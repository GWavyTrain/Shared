# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output, display

# %config InlineBackend.figure_format = 'retina'
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

import PhenomA as pa
import LISA as li
import WaveformTools as wt
reload(wt)
# Out:
# <module 'WaveformTools' from 'WaveformTools.pyc'>

# %% [markdown]
# # Setup LISA object, load sky & polarization averaged transfer function, plot sensitivity curve
#
#
# ### LISA object options
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; Tobs, default=4 yr ---- example: lisa = li.LISA(Tobs=li.YEAR)
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; Larm, default=2.5e9 (meters)
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; NC,   default=2 (number of data channels, 1 or 2)

# %%
# create LISA object
lisa = li.LISA() 

# Plot LISA's sensitivity curve
f  = np.logspace(np.log10(1.0e-5), np.log10(1.0e0), 1000)
Sn = lisa.Sn(f)
li.PlotSensitivityCurve(f, Sn) # provide additional argument, e.g. 'SensitivityCurve.pdf', to save figure

# %%
import matplotlib.colors as mcolors
import matplotlib.cm as cm


# Choose a colormap
colormap = cm.summer_r
colormap = cm.Purples
colormap2= cm.Blues
#colormap = cm.Reds_r

normalize = mcolors.Normalize(vmin=80, vmax=240)

data=np.genfromtxt('BH_data.txt', dtype=None, delimiter=" ",names=True)
#print data['mass1']

m1 = data['M1']*pa.TSUN/2e33 
m2 = data['M2']*pa.TSUN/2e33
m2new= data['M_BH2']*pa.TSUN/2e33
znew= data['newredshift']
zold= data['r_z']
f_start  = data['newredshift']*0.0+ 1.e-4
#print(lisa.Tobs)
Tobs=data['newredshift']*0+lisa.Tobs
Mold = m1 + m2 # total mass
Mnew =m1+m2new
etaold = m1*m2/M**2 # symmetric mass ratio
Mcold=Mold*etaold**(3./5)
etanew = m1*m2new/Mnew**2 # symmetric mass ratio
Mcnew=Mnew*etanew**(3./5)


theta = 0.57 #RA=153 deg =2.6 rad
phi = 0.63 #dec = +54 deg astro, 36 deg phys = 0.63 rad
iota = 0.0

fig, ax = plt.subplots(1, figsize=(8,6))
plt.tight_layout()

ax.set_xlabel(r'f [Hz]', fontsize=20, labelpad=10)
ax.set_ylabel(r'Characteristic Strain', fontsize=20, labelpad=10)
ax.tick_params(axis='both', which='major', labelsize=20)
        
ax.set_xlim(1.0e-5, 1.0e0)
ax.set_ylim(3.0e-22, 1.0e-15)

f = np.logspace(np.log10(1.0e-5), np.log10(1.0e0), 1000)
ax.loglog(f, np.sqrt(f*lisa.Sn(f)),color='xkcd:chocolate')
colors = plt.cm.cool(np.linspace(0,1,len(data['newredshift'])))


for j in range(len(data['newredshift'])):
    print(j)
    m1[j]=m1[j]+j*pa.TSUN
    binary = wt.Binary(m1[j], m2[j], zold[j])
    binary.f_start = f_start[j]    
    binarynew = wt.Binary(m1[j], m2new[j], znew[j])
    binarynew.f_start = f_start[j]
#print(binary.f_start)

    binary.T_merge = 5.*Mcold[j]/(8.*np.pi*binary.f_start*Mcold[j])**(8./3.)   
    binarynew.T_merge = 5.*Mcnew[j]/(8.*np.pi*binarynew.f_start*Mcnew[j])**(8./3.)

#print(Tobs)
      
#    if (any(binary.T_merge) > any(Tobs)):
#    binary.f_end = (5.*Mc[j]/(np.abs(Tobs[j]-binary.T_merge)))**(3./8.)/(8.*np.pi*Mc[j])
#else:
    binary.f_end = pa.get_freq(Mold[j], etaold[j], "cut") # PhenomA cut-off frequency i.e. frequency upper bound  
    binarynew.f_end = pa.get_freq(Mnew[j], etanew[j], "cut") # PhenomA cut-off frequency i.e. frequency upper bound    
        
#Delta_logf = np.log(binary.f_end) - np.log(binary.f_start)

#    binary.SetFreqBounds(lisa)

#print(f_end)

#for j in range(len(data['redshift'])):
#print(lisa)

    freqs, X_char = binary.CalcStrain(lisa)
    snr = binary.CalcSNR(freqs, X_char, lisa)
    print("\nSNR........ {}".format(snr))
    color = colormap(normalize(snr))
    ax.loglog(freqs, np.sqrt(freqs)*X_char, color='xkcd:slime green') 
    freqsnew, X_charnew = binarynew.CalcStrain(lisa)
    snrnew = binarynew.CalcSNR(freqsnew, X_charnew, lisa)
    print("\nSNR........ {}".format(snrnew))
    color2 = colormap2(normalize(snrnew))
    ax.loglog(freqsnew, np.sqrt(freqsnew)*X_charnew, color='xkcd:plum') 
#binary.PlotStrain(freqs, X_char, lisa)

plt.savefig('Justin.SN.BH.pdf', bbox_inches='tight')
# Out:
# 0
# Redshift provided.
# 	Luminosity Distance........... 250212.571052 Mpc
# Redshift provided.
# 	Luminosity Distance........... 170755.702732 Mpc
#
# SNR........ 115.689513228
#
# SNR........ 113.402795208
# 1
# Redshift provided.
# 	Luminosity Distance........... 185335.553941 Mpc
# Redshift provided.
# 	Luminosity Distance........... 139016.284934 Mpc
#
# SNR........ 125.647775476
#
# SNR........ 169.081817069
# 2
# Redshift provided.
# 	Luminosity Distance........... 185335.553941 Mpc
# Redshift provided.
# 	Luminosity Distance........... 139016.284934 Mpc
#
# SNR........ 125.605995767
#
# SNR........ 168.484138543
# 3
# Redshift provided.
# 	Luminosity Distance........... 185335.553941 Mpc
# Redshift provided.
# 	Luminosity Distance........... 139016.286167 Mpc
#
# SNR........ 165.963644981
#
# SNR........ 264.220171776
# 4
# Redshift provided.
# 	Luminosity Distance........... 185335.553941 Mpc
# Redshift provided.
# 	Luminosity Distance........... 139016.287401 Mpc
#
# SNR........ 125.647754136
#
# SNR........ 169.009155109
# 5
# Redshift provided.
# 	Luminosity Distance........... 171067.089022 Mpc
# Redshift provided.
# 	Luminosity Distance........... 131044.317784 Mpc
#
# SNR........ 128.546080597
#
# SNR........ 186.828312699
# 6
# Redshift provided.
# 	Luminosity Distance........... 148582.897445 Mpc
# Redshift provided.
# 	Luminosity Distance........... 117666.068625 Mpc
#
# SNR........ 239.721312407
#
# SNR........ 297.075492476
# 7
# Redshift provided.
# 	Luminosity Distance........... 148582.897445 Mpc
# Redshift provided.
# 	Luminosity Distance........... 117666.060098 Mpc
#
# SNR........ 177.968063915
#
# SNR........ 278.82120839
# 8
# Redshift provided.
# 	Luminosity Distance........... 131613.765892 Mpc
# Redshift provided.
# 	Luminosity Distance........... 106868.668784 Mpc
#
# SNR........ 184.16254968
#
# SNR........ 287.913774337
# 9
# Redshift provided.
# 	Luminosity Distance........... 131613.765892 Mpc
# Redshift provided.
# 	Luminosity Distance........... 106868.68329 Mpc
#
# SNR........ 138.931751635
#
# SNR........ 251.962353777
# 10
# Redshift provided.
# 	Luminosity Distance........... 131613.765892 Mpc
# Redshift provided.
# 	Luminosity Distance........... 106868.68329 Mpc
#
# SNR........ 184.374958744
#
# SNR........ 287.902631487
# 11
# Redshift provided.
# 	Luminosity Distance........... 118287.778529 Mpc
# Redshift provided.
# 	Luminosity Distance........... 97943.9536791 Mpc
#
# SNR........ 143.298249827
#
# SNR........ 277.362567299
# 12
# Redshift provided.
# 	Luminosity Distance........... 118287.778529 Mpc
# Redshift provided.
# 	Luminosity Distance........... 97943.9515186 Mpc
#
# SNR........ 189.866626656
#
# SNR........ 296.634030231
# 13
# Redshift provided.
# 	Luminosity Distance........... 118287.778529 Mpc
# Redshift provided.
# 	Luminosity Distance........... 97943.948998 Mpc
#
# SNR........ 143.685768086
#
# SNR........ 280.528661796
# 14
# Redshift provided.
# 	Luminosity Distance........... 118287.778529 Mpc
# Redshift provided.
# 	Luminosity Distance........... 97943.961481 Mpc
#
# SNR........ 190.973122753
#
# SNR........ 296.31087483
# 15
# Redshift provided.
# 	Luminosity Distance........... 118287.778529 Mpc
# Redshift provided.
# 	Luminosity Distance........... 97943.9566799 Mpc
#
# SNR........ 143.690351527
#
# SNR........ 280.538866083
# 16
# Redshift provided.
# 	Luminosity Distance........... 118287.778529 Mpc
# Redshift provided.
# 	Luminosity Distance........... 97943.9536791 Mpc
#
# SNR........ 143.523147304
#
# SNR........ 278.982204763
# 17
# Redshift provided.
# 	Luminosity Distance........... 118287.778529 Mpc
# Redshift provided.
# 	Luminosity Distance........... 97943.9596806 Mpc
#
# SNR........ 190.977307601
#
# SNR........ 296.317944727
# 18
# Redshift provided.
# 	Luminosity Distance........... 118287.778529 Mpc
# Redshift provided.
# 	Luminosity Distance........... 97943.95716 Mpc
#
# SNR........ 143.697226168
#
# SNR........ 280.554207261
# 19
# Redshift provided.
# 	Luminosity Distance........... 118287.778529 Mpc
# Redshift provided.
# 	Luminosity Distance........... 97943.9622012 Mpc
#
# SNR........ 143.454319403
#
# SNR........ 278.697308465
# 20
# Redshift provided.
# 	Luminosity Distance........... 118287.778529 Mpc
# Redshift provided.
# 	Luminosity Distance........... 97943.95716 Mpc
#
# SNR........ 190.784656036
#
# SNR........ 296.406820151
# 21
# Redshift provided.
# 	Luminosity Distance........... 118287.778529 Mpc
# Redshift provided.
# 	Luminosity Distance........... 97943.9575201 Mpc
#
# SNR........ 143.704100184
#
# SNR........ 280.569547664
# 22
# Redshift provided.
# 	Luminosity Distance........... 118287.778529 Mpc
# Redshift provided.
# 	Luminosity Distance........... 97943.9549995 Mpc
#
# SNR........ 190.429035973
#
# SNR........ 296.50357651
# 23
# Redshift provided.
# 	Luminosity Distance........... 118287.778529 Mpc
# Redshift provided.
# 	Luminosity Distance........... 97943.9477977 Mpc
#
# SNR........ 190.985676137
#
# SNR........ 296.332092198
# 24
# Redshift provided.
# 	Luminosity Distance........... 118287.778529 Mpc
# Redshift provided.
# 	Luminosity Distance........... 97943.9507984 Mpc
#
# SNR........ 143.710973574
#
# SNR........ 280.584909944
# 25
# Redshift provided.
# 	Luminosity Distance........... 118287.778529 Mpc
# Redshift provided.
# 	Luminosity Distance........... 97943.95704 Mpc
#
# SNR........ 143.713264565
#
# SNR........ 280.590003466
# 26
# Redshift provided.
# 	Luminosity Distance........... 118287.778529 Mpc
# Redshift provided.
# 	Luminosity Distance........... 97943.9501983 Mpc
#
# SNR........ 190.989859825
#
# SNR........ 296.33915572
# 27
# Redshift provided.
# 	Luminosity Distance........... 112631.919815 Mpc
# Redshift provided.
# 	Luminosity Distance........... 94033.6559258 Mpc
#
# SNR........ 145.775040744
#
# SNR........ 292.277001896
# 28
# Redshift provided.
# 	Luminosity Distance........... 112631.919815 Mpc
# Redshift provided.
# 	Luminosity Distance........... 94033.6468346 Mpc
#
# SNR........ 145.837891052
#
# SNR........ 292.793905584
# 29
# Redshift provided.
# 	Luminosity Distance........... 112631.919815 Mpc
# Redshift provided.
# 	Luminosity Distance........... 94033.6486289 Mpc
#
# SNR........ 193.625906785
#
# SNR........ 300.56037393
# 30
# Redshift provided.
# 	Luminosity Distance........... 112631.919815 Mpc
# Redshift provided.
# 	Luminosity Distance........... 94033.6544903 Mpc
#
# SNR........ 194.000572356
#
# SNR........ 300.462974693
# 31
# Redshift provided.
# 	Luminosity Distance........... 107506.286763 Mpc
# Redshift provided.
# 	Luminosity Distance........... 90425.6031449 Mpc
#
# SNR........ 148.06541336
#
# SNR........ 305.222465518
# 32
# Redshift provided.
# 	Luminosity Distance........... 107506.286763 Mpc
# Redshift provided.
# 	Luminosity Distance........... 90425.5949185 Mpc
#
# SNR........ 196.694394298
#
# SNR........ 304.562030366
# 33
# Redshift provided.
# 	Luminosity Distance........... 87735.0206848 Mpc
# Redshift provided.
# 	Luminosity Distance........... 75921.5469528 Mpc
#
# SNR........ 157.847627688
#
# SNR........ 356.812719931

# %% [markdown]
# # Just a check to make sure the averaging of polarization was done correctly
#     # The answer (SNR) should be ~ 140

# %%
print(pa.TSUN)
for j in range(len(data['redshift'])):
    print(j,M[j]/pa.TSUN,z[j])
# Out:
# 4.9169e-06
# (0, 53350.0, 21.506)
# (1, 53308.0, 16.4)
# (2, 53285.99999999999, 16.4)
# (3, 79855.0, 16.4)
# (4, 53304.99999999999, 16.4)
# (5, 53296.0, 15.263)
# (6, 106498.99999999999, 13.458)
# (7, 80037.00000000001, 13.458)
# (8, 79872.00000000001, 12.083)
# (9, 53304.0, 12.083)
# (10, 79913.0, 12.083)
# (11, 53182.0, 10.994)
# (12, 79583.0, 10.994)
# (13, 53348.99999999999, 10.994)
# (14, 80021.0, 10.994)
# (15, 53348.99999999999, 10.994)
# (16, 53274.99999999999, 10.994)
# (17, 80021.0, 10.994)
# (18, 53348.99999999999, 10.994)
# (19, 53241.99999999999, 10.994)
# (20, 79918.0, 10.994)
# (21, 53348.99999999999, 10.994)
# (22, 79788.0, 10.994)
# (23, 80021.0, 10.994)
# (24, 53348.99999999999, 10.994)
# (25, 53348.99999999999, 10.994)
# (26, 80021.0, 10.994)
# (27, 53279.00000000001, 10.529)
# (28, 53304.99999999999, 10.529)
# (29, 79882.0, 10.529)
# (30, 80021.0, 10.529)
# (31, 53325.0, 10.106)
# (32, 79930.0, 10.106)
# (33, 53156.0, 8.458)

# %%
# sky, iota, and polarization averaged response
m1 = 0.50*pa.TSUN 
m2 = 0.25*pa.TSUN
Dl = 1.0e-3*wt.MPC
f_start  = 2.6e-3

binary = wt.Binary(m1, m2, Dl=Dl)
binary.f_start = f_start
binary.SetFreqBounds(lisa)

freqs, X_char = binary.CalcStrain(lisa)
snr = binary.CalcSNR(freqs, X_char, lisa)
print("\nSNR........ {}".format(snr))
binary.PlotStrain(freqs, X_char, lisa)
# Out:
# Luminosity Distance provided.
# 	redshift........... 2.31173518649e-07
#
# SNR........ 139.707047722

# %%
# numerically check that this polarization averaged result, when numerically averaged over theta, phi, iota,
#    return the numerically averaged result
num = 30
theta_arr = np.linspace(0, np.pi, num)
phi_arr = np.linspace(0, 2*np.pi, num)
iota_arr = np.linspace(0, np.pi, num)

tot = 0.0

for i in range(num):
    theta = theta_arr[i]
    for j in range(num):
        phi = phi_arr[j]
        for k in range(num):
            iota = iota_arr[k]
            freqs, X_char = binary.CalcStrain(lisa, theta, phi, iota)
            snr = binary.CalcSNR(freqs, X_char, lisa)

            tot += snr**2

avg_snr = np.sqrt(tot/num**3)
print(avg_snr)
# Out:
# 160.11082671653546
